# %%
# 구글드라이브 구글코랩에 연동(마운트)
from google.colab import drive
drive.mount('/content/drive')

# %%
# Google Drive의 디렉토리로 이동
# %cd /content/drive/MyDrive/Colab Notebooks/Generative_Deep_Learning_2nd_Edition/Generative_Deep_Learning_2nd_Edition/notebooks/08_diffusion/01_ddm

# %%
# !pwd

# %%
# Git 설정
# !git config --global user.name "kmakdh3692"
# !git config --global user.email "kmakdh3692@gmail.com"

# %%
# 깃 상태 확인
# !git status

# %%
# 깃 초기화
# !git init
# !git status

# %%
# 경로 재설정
# !git remote set-url origin https://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@github.com/kmakdh3692/Generative_Deep_Learning_2nd_Edition.git

# %%
# add / push
# !git add .
# !git commit -m "Initial commit with files"

# %%
# !git push origin master
